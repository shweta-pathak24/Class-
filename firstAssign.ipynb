# %% [markdown]
# 1. Write a program to display:
# value
# type
# memory address for a variable using appropriate built-in functions.

# %%
a = 10
b = 20
c = a + b
print(c)
print(type(c))
print(id(c))
# Out:
# 30
# <class 'int'>
# 140707369301832

# %% [markdown]
# 2. What is the difference between :
# a = 10
# b= 10
# and
# a=[10]
# b=[10]
#
# Explain using id().

# %%
a = 10
b= 10
print("a:",a)       #tuple is immutable that's why they share the address
print(id(a))

print("b:", b)
print(id(b))
# Out:
# a: 10
# 140707369301192
# b: 10
# 140707369301192

# %%
a=[10]
b=[10]
print(id(a))        #list is mutable that's why the adress is change from b
print(id(b))
# Out:
# 2463314316608
# 2463314325376

# %% [markdown]
# 3. What does the id() function return?
# IS the value returned by id() same for two variables holding the same value?

# %%
a = 10
b = 10
print(id(a))
print(id(b))

#yes the if two variable holding the same value then the addresss is same for both
# Out:
# 140707369301192
# 140707369301192

# %% [markdown]
# 4. What is the size of getsizeof()?
# Why is memory size different for different data types?

# %%
from sys import getsizeof
x = 5
print(getsizeof(x))

y = 5.5
print(getsizeof(y))

# Beacuse diff data types stores diff data
# Out:
# 28
# 24

# %% [markdown]
# 5. Predict the output:
# a = 10
# b = 10
# print(id(a) == id(b))
#
# Expain why this happens.

# %%
a = 10
b = 10
print(id(a) == id(b))

#This is happens because, the memory address of a and b is same because the value of a and b is same it point out to the one value.
# Out:
# True

# %% [markdown]
# 6. Write a program that accepts two numbers from user and prints their:
# addition
# Subtraction
# Multiplication
# Division

# %%
first_number = int(input("Enter a first number:"))
second_number = int(input("Enter a Second number:"))

print("Addition is:",first_number + second_number)
print("Subtraction is:",first_number - second_number)
print("Multiplication is:",first_number * second_number)
print("Division is:",first_number / second_number)
# Out:
# Addition is: 3
# Subtraction is: -1
# Multiplication is: 2
# Division is: 0.5

# %% [markdown]
# 7. Why does the input() function always return a string?
# How can you convert it ti another data type?

# %%
# the input() function always return a string because it is use for the read the text which is written by the user.

# %% [markdown]
# 8. Predict the output:
# x = input("Enter number: ")
# print(type(x))
# Explain the reason.

# %%
x = input("Enter number: ")
print(type(x))
# because input function always returns a string
# Out:
# <class 'str'>

# %% [markdown]
# 9. Write a program to take user's name and age and display:
# H?ello <name> , you will turn <age+1> next year.

# %%
name = input("Enter a name:")
age = int(input("Enter a age: "))

print(f"Hello {name}, you will turn {age+1} next year")
# Out:
# Hello Shweta, you will turn 24 next year

# %% [markdown]
# 10. What will be the output:
# print("10" +"20")
# print(10 + 20)
# Explain the difference.

# %%
print("10" +"20")
print(10 + 20)

# the difference is that first is the string thats why the output is 1020 and second is the int thats why they give the sum og 10 and 20
# Out:
# 1020
# 30
